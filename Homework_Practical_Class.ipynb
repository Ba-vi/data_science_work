# %% [markdown]
# # **Homework**
#
#
# ---

# %% [markdown]
# # from sklearn.linear_model import LinearRegression
# # import numpy as np
#
# # Step 1: Input Data
# # Years of Experience
# # X = np.array([[1], [2], [3], [4], [5]])
#
# # Salaries
# # y = np.array([30000, 35000, 40000, 45000, 50000])
#
# # Step 2: Create the model
# # model = LinearRegression()
#
# # TODO: Train the model
# # model._fit(x,y) (fill in the blank)
# # model.fit(X,y)
#
# # Step 3: Predict a salary
# # TODO: Predict salary for 6 years experience
# # prediction = model.______ (fill in the blank)
#
# # print("Predicted salary for 6 years of experience:", prediction[0])

# %% [markdown]
# # TODO: Now plot this graph with the predicted value displayed as a green point
# # ...

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([30000, 35000, 40000, 45000, 50000])

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
size = 6
prediction = model.predict([[size]])
print("Predicted salary for 6 years of experience:", prediction[0])
# Out:
# Predicted salary for 6 years of experience: 55000.0

# %%
plt.scatter(X,y ,color="blue",label="Data points")
plt.plot(X,model.predict(X),color="red",label="Regression Line")
plt.scatter(size,prediction,color="green",marker="o",s=120,label="predicted value")
plt.xlabel("Years of experience")
plt.ylabel("salaries")
plt.legend()
plt.show()
